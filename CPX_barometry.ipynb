# %%
setwd('/Users/TES/Desktop/Jupyter')
df <- read.table("CPX_experiments.txt",sep="\t",header=TRUE)

# %%
plot(df$Al2O3.liq,df$Al2O3.cpx)
# Out:
# plot without title

# %% [markdown]
# Luca slides. https://www.unige.ch/sciences/terre/
