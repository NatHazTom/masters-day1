# %% [markdown]
# Now that we have learnt to fit linear and nonlinear regressions, the aim is to fit and compare models to estimate pressure using cpx chemistry.
#
# Choose an independent variable (X-variable) to fit to Pressure. Then fit a statistical model and examine how well the model fits the data. Find which chemical elements and which type of relationship (linear vs. nonlinear) best fit the data. You can compare the results using the R<sup>2</sup> value and the graph plotted below with the fitted line.

# %%
df <- read.table("CPX_experiments.txt",sep="\t",header=TRUE)

# %%
Y <- df$P_GPa
X <- df$Al2O3.cpx
ylab <- "Pressure (GPa)"
xlab <- "Al2O3 (wt. %)"

plot(X,Y,xlab=xlab,ylab=ylab)
# Out:
# plot without title

# %%
model.data <- data.frame(Y,X)
linearMod <- lm(Y ~ X, data=model.data)
summary(linearMod)

plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(linearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ X, data = model.data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3373 -0.3312 -0.0734  0.3104  3.3292
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.125077   0.032392  -3.861 0.000118 ***
# X            0.162757   0.004809  33.842  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6149 on 1349 degrees of freedom
# Multiple R-squared:  0.4592,	Adjusted R-squared:  0.4588
# F-statistic:  1145 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title

# %%
nonlinearMod <- lm(Y ~ I(X^0.5), data=model.data)
print(nonlinearMod)
summary(nonlinearMod)

plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(nonlinearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ I(X^0.5), data = model.data)
#
# Coefficients:
# (Intercept)     I(X^0.5)
#     -0.9669       0.7763
# Call:
# lm(formula = Y ~ I(X^0.5), data = model.data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0525 -0.3503 -0.0636  0.3310  3.2503
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.96688    0.05757  -16.79   <2e-16 ***
# I(X^0.5)     0.77627    0.02397   32.38   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6272 on 1349 degrees of freedom
# Multiple R-squared:  0.4373,	Adjusted R-squared:  0.4369
# F-statistic:  1049 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# QUESTION: USING ALUMINIMUM, WHAT HAPPENS IF WE PERFORM THE REGRESSION Y ~ X<sup>0.5</sup> ?
#
# QUESTION: BASED ON PART A, CHOOSE ANOTHER ELEMENT THAT CORRELATES  WITH PRESSURE, WHAT IS THE BEST FIT (X, X<sup>0.5</sup>, OR, X<sup>2</sup>) ?
#
# QUESTION: AND WHAT ABOUT TEMPERATURE?
